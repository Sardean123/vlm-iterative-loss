# %%
from diffusers import StableDiffusionPipeline
import torch
# Out:
# /Users/deancasey/Documents/Columbia/vlm-iterative-loss/info_loss/lib/python3.12/site-packages/torch/amp/autocast_mode.py:270: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(

# %%
model_id = "runwayml/stable-diffusion-v1-5"
pip = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float16,
)
pip = pip.to("cuda")

prompt = "Generate an image based on this caption: "

image = pip(
    prompt=prompt,
    num_inference_steps=50
    guidance_scale=7.5  # Need to figure out what this is
).images[0]
